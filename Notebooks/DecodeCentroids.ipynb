# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import  load_model

centroids = np.load("../Data/HIV/c3h5.npy")
print(f"{centroids.shape}")
# Out:
# 2025-10-21 15:43:16.160372: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-21 15:43:16.160649: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-21 15:43:16.194078: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
decoder = load_model("../Models/Decoder/decoder.keras")
decoder.summary()
# Y = decoder.predict(centroids)
# del centroids
# del decoder
# print(Y)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
mzs = np.load("../Models/Decoder/common_mzs.npy")
import matplotlib.pyplot as plt

colors = ['blue', 'green', 'red']
labels = [f'Centroid {i+1}' for i in range(Y.shape[0])]
fig, axes = plt.subplots(1, Y.shape[0], figsize=(5 * Y.shape[0], 4), sharey=True)
for i in range(Y.shape[0]):
    axes[i].plot(mzs, Y[i], color=colors[i], label=labels[i])
    axes[i].set_xlabel('m/z')
    axes[i].set_title(labels[i])
    axes[i].legend()
axes[0].set_ylabel('Intensity')
plt.tight_layout()
plt.show()
